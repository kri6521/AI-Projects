# %%
from keras.preprocessing import image   # works like openCv(helps working with img)
from tensorflow.keras.preprocessing.image import ImageDataGenerator      # imgs generate krne me help krega

# %%
img = image.load_img('/content/cat_image.jpeg',target_size=(200,200))

# %%
import matplotlib.pyplot as plt

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
type(img)   # this is not a numpy array
# Out:
# PIL.Image.Image

# %%
# imagedatagenerator class ka object bnaya datagen bolkr
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,  # img ko khskana
    height_shift_range=0.2,
    shear_range=0.2,    # 1 k scale pr 0.2 ka distortion
    zoom_range=0.2,
    horizontal_flip=True,
)

# %%
img = image.img_to_array(img)
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch = img.reshape(1,200,200,3)   # itte dimension ka ek img

# %%
# we use flow while applying to single image
i=0

for output in datagen.flow(input_batch,batch_size=1,save_to_dir='aug'):
  i+=1
  if i==10:     # total 10 images will be formed
    break


'''
train_generator = train_datagen.flow_from_directory(
        'data/train',  # this is the target directory
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')   #since we use binary_crossentropy loss, we need binary tools

validation_generator = test_datagen.flow_from_directory(
        'data/validation',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')

// data augmentation krke jo images aaye wai training k time p use honge
model.fit_generator(
        train_generator,
        steps_per_epoch=2000 // batch_size,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=800 // batch_size)
'''
# Out:
# "\ntrain_generator = train_datagen.flow_from_directory(\n        'data/train',  # this is the target directory\n        target_size=(150, 150),\n        batch_size=32,\n        class_mode='binary')   #since we use binary_crossentropy loss, we need binary tools\n\nvalidation_generator = test_datagen.flow_from_directory(\n        'data/validation',\n        target_size=(150, 150),\n        batch_size=32,\n        class_mode='binary')\n\n// data augmentation krke jo images aaye wai training k time p use honge\nmodel.fit_generator(\n        train_generator,\n        steps_per_epoch=2000 // batch_size,\n        epochs=50,\n        validation_data=validation_generator,\n        validation_steps=800 // batch_size)\n"

# %%
input_batch.shape
# Out:
# (1, 200, 200, 3)
